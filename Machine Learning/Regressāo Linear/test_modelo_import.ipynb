# %%
import pickle

# %%
modelo = open('modelo_consumo_cerveja', 'rb') #read binary
lm_new = pickle.load(modelo)
modelo.close()

# %%
dados=[[27,30.5,23,12.2,0]]

# %%
lm_new.predict(dados)
# Out:
# array([26548.32961054])
